# %% [markdown]
# ![logo_chico_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **pandas** es una herramienta de manipulación y análisis de datos de código abierto construida sobre el lenguaje de programación **Python** .
#
# Algunas de las principales características de esta librería son:
#
# * Define nuevas estructuras de datos basadas en los arrays de la librería NumPy pero con nuevas funcionalidades.
# * Permite leer y escribir fácilmente archivos en formato CSV, Excel y bases de datos SQL.
# * Permite acceder a los datos mediante índices o nombres para filas y columnas.
# * Ofrece métodos para reordenar, dividir y combinar conjuntos de datos.

# %% [markdown]
# Link de Interés:
#
# https://pandas.pydata.org/
#
# https://pandas.pydata.org/docs/

# %%
import pandas as pd

# %% [markdown]
# ### ¿Qué estructuras de datos maneja pandas?

# %% [markdown]
# Pandas dispone de tres estructuras de datos diferentes:
#
# * **Series:** Estructura de una dimensión.
# * **DataFrame:** Estructura de dos dimensiones (tablas).
# * **Panel:** Estructura de tres dimensiones (cubos).

# %% [markdown]
# #### Series

# %% [markdown]
# La **serie** es una matriz unidimensional etiquetada capaz de contener cualquier tipo de datos (enteros, cadenas, números de punto flotante, objetos Python, etc.). Son homogéneas, es decir, sus elementos tienen que ser del mismo tipo, y su tamaño es inmutable (no se puede cambiar) aunque si su contenido.
#
# Son estructuras similares a los arrays de una dimensión.

# %%
#Serie creada con una lista
una_serie = pd.Series(['Juan', 'María', 'Pedro', 'José', 'Catalina','Paula'], dtype='string')
print(una_serie)
# Out:
# 0        Juan
# 1       María
# 2       Pedro
# 3        José
# 4    Catalina
# 5       Paula
# dtype: string

# %%
#Serie creada con un diccionario
otra_serie = pd.Series({'Juan': 8.5,  'Catalina': 7, 'Pedro': 10 , 'Mariela': 6})
print(otra_serie)
# Out:
# Juan         8.5
# Catalina     7.0
# Pedro       10.0
# Mariela      6.0
# dtype: float64

# %% [markdown]
# Métodos para ver las características de una serie:
#
# * size :  Devuelve el número de elementos de la serie.
# * index : Devuelve una lista con los nombres de las filas.
# * dtype : Devuelve el tipo de datos de los elementos de la serie s.

# %%
print(f'size {una_serie.size}')
print(f'index {una_serie.index}')
print(f'dtype {una_serie.dtype}')
# Out:
# size 6
# index RangeIndex(start=0, stop=6, step=1)
# dtype string

# %%
print(f'size {otra_serie.size}')
print(f'index {otra_serie.index}')
print(f'dtype {otra_serie.dtype}')
# Out:
# size 4
# index Index(['Juan', 'Catalina', 'Pedro', 'Mariela'], dtype='object')
# dtype float64

# %% [markdown]
# Para acceder a los elementos de una serie se puede realizar por índice o por posición:
#
# * serie[i] : Devuelve el elemento que ocupa la posición i+1 en la serie s.
# * serie[posiciones]: Devuelve otra serie con los elementos que ocupan las posiciones de la lista posiciones.
# * serie[nombre] : Devuelve el elemento con el nombre nombre en el índice.
# * serie[nombres] : Devuelve otra serie con los elementos correspondientes a los nombres indicadas en la lista nombres en el índice.

# %%
print(una_serie[0])
# Out:
# Juan

# %%
print(una_serie[0:5])
print(una_serie[[1,2]])
# Out:
# 0        Juan
# 1       María
# 2       Pedro
# 3        José
# 4    Catalina
# dtype: string
# 1    María
# 2    Pedro
# dtype: string

# %%
print(otra_serie['Juan'])
# Out:
# 8.5

# %%
print(otra_serie[['Juan','Catalina']])
# Out:
# Juan        8.5
# Catalina    7.0
# dtype: float64

# %% [markdown]
# #### DataFrame

# %% [markdown]
# Un **DataFrame** es una estructura de datos bidimensional donde cada columna es un objeto de tipo Series. Todos los datos de una misma columna son del mismo tipo, y las filas son registros que pueden contener datos de distintos tipos.
#
# Un DataFrame contiene dos índices, uno para las filas y otro para las columnas, y se puede acceder a sus elementos mediante los nombres de las filas y las columnas.
#
# Se puede pensar como una una tabla SQL. Generalmente es el objeto pandas más utilizado.

# %%
#DataFrame a partir de una lista
df1 = pd.DataFrame([['Juan','Pérez',25,'Ingeniero'], ['Luis','Gómez',30,'Abogado'], ['Antonio','Sánchez',20,'Médico']], columns=['nombre', 'apellido','edad','profesion'])
print(df1)
# Out:
#     nombre apellido  edad  profesion
# 0     Juan    Pérez    25  Ingeniero
# 1     Luis    Gómez    30    Abogado
# 2  Antonio  Sánchez    20     Médico

# %%
#DataFrame a partir de un diccionario
datos = {'nombre':['Juan', 'Luis', 'Antonio'],
         'apellido':['Pérez','Gómez','Sánchez'],
         'edad':[25, 30, 35],
         'profesion':['Ingeniero', 'Abogado', 'Médico']
         }

df2 = pd.DataFrame(datos)
print(df2)
# Out:
#     nombre apellido  edad  profesion
# 0     Juan    Pérez    25  Ingeniero
# 1     Luis    Gómez    30    Abogado
# 2  Antonio  Sánchez    35     Médico

# %% [markdown]
# Métodos para ver las características de un DataFrame:
#
# * info : Devuelve información (número de filas, número de columnas, índices, tipo de las columnas y memoria usado) sobre el DataFrame.
# * shape : Devuelve una tupla con el número de filas y columnas del DataFrame.
# * size : Devuelve el número de elementos del DataFrame.
# * columns : Devuelve una lista con los nombres de las columnas del DataFrame.
# * index : Devuelve una lista con los nombres de las filas del DataFrame df.
# * dtypes : Devuelve una serie con los tipos de datos de las columnas del DataFrame.
# * head(n) : Devuelve las n primeras filas del DataFrame.
# * tail(n) : Devuelve las n últimas filas del DataFrame.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nombre     3 non-null      object
#  1   apellido   3 non-null      object
#  2   edad       3 non-null      int64
#  3   profesion  3 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 224.0+ bytes

# %%
df1.dtypes
# Out:
# nombre       object
# apellido     object
# edad          int64
# profesion    object
# dtype: object

# %%
df1.head(1)
# Out:
#   nombre apellido  edad  profesion
# 0   Juan    Pérez    25  Ingeniero

# %%
df1.tail(2)
# Out:
#     nombre apellido  edad profesion
# 1     Luis    Gómez    30   Abogado
# 2  Antonio  Sánchez    20    Médico

# %% [markdown]
# El acceso a los datos de un DataFrame se puede hacer a través de posiciones o través de los nombres de las filas y columnas.
#
# *Accesos mediante posiciones*
#
# * df.iloc[i, j] : Devuelve el elemento que se encuentra en la fila i y la columna j del DataFrame df. Pueden indicarse secuencias de índices para obtener partes del DataFrame.
# * df.iloc[filas, columnas] : Devuelve un DataFrame con los elementos de las filas de la lista filas y de las columnas de la lista columnas.
# * df.iloc[i] : Devuelve una serie con los elementos de la fila i del DataFrame df.
#
# *Acceso a los elementos mediante nombres*
#
# * df.loc[fila, columna] : Devuelve el elemento que se encuentra en la fila con nombre fila y la columna de con nombre columna del DataFrame df.
# * df.loc[filas, columnas] : Devuelve un DataFrame con los elemento que se encuentra en las filas con los nombres de la lista filas y las columnas con los nombres de la lista columnas del DataFrame df.
# * df[columna] : Devuelve una serie con los elementos de la columna de nombre columna del DataFrame df.
# * df.columna : Devuelve una serie con los elementos de la columna de nombre columna del DataFrame df. Es similar al método anterior pero sólo funciona cuando el nombre de la columna no tiene espacios en blanco.

# %%
df1['apellido']
# Out:
# 0      Pérez
# 1      Gómez
# 2    Sánchez
# Name: apellido, dtype: object

# %%
df1.apellido
# Out:
# 0      Pérez
# 1      Gómez
# 2    Sánchez
# Name: apellido, dtype: object

# %%
df1.loc[1,'apellido']
# Out:
# 'Gómez'

# %%
df1.iloc[0]
# Out:
# nombre            Juan
# apellido         Pérez
# edad                25
# profesion    Ingeniero
# Name: 0, dtype: object

# %%
df1.iloc[0,0]
# Out:
# 'Juan'

# %% [markdown]
# ##### Creación de DataFrame desde un archivo de datos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df3=pd.read_csv('/content/drive/MyDrive/Labo Datos/Notebooks Ciencia de Datos/datasets/ds_titanic.csv')
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df3.to_csv('/content/drive/MyDrive/Labo Datos/Notebooks Ciencia de Datos/datasets/archivo_output.csv',index=False)

# %% [markdown]
# ### Filtrar información

# %% [markdown]
# Crear máscaras para obtener las filas que cumplen con el patrón buscado

# %%
df3["Sex"]=="male"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %% [markdown]
# OR

# %%
(df3["Sex"]=="male") | (df3["Pclass"] ==1)
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Length: 891, dtype: bool

# %% [markdown]
# AND

# %%
(df3["Sex"]=="male") & (df3["Pclass"] ==1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Length: 891, dtype: bool

# %% [markdown]
# Utilizamos las máscaras para selccionar filas

# %%
df3[(df3["Sex"]=="male") | (df3["Pclass"] ==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
filtro=(df3["Sex"]=="male") | (df3["Pclass"] ==1)
df3[filtro]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Creación de nuevas columnas

# %% [markdown]
# Creación de columna en función de la suma de los datos en otras 2

# %%
df3["SibSp_Parch"]=df3["SibSp"]+df3["Parch"]
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  SibSp_Parch
# 0      0         A/5 21171   7.2500   NaN        S            1
# 1      0          PC 17599  71.2833   C85        C            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S            0
# ...

# %% [markdown]
# Eliminar columna

# %%
df3.drop("SibSp_Parch",axis=1,inplace=True)
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
columnas_eliminar=["PassengerId","Name"]
df3.drop(columnas_eliminar,axis=1,inplace=True)
df3.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %% [markdown]
# Eliminar filas

# %%
mascara=df3["Sex"]=="male"
df3.drop(df3[mascara].index)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 8           1       3  female  27.0      0      2            347742  11.1333
# 9           1       2  female  14.0      1      0            237736  30.0708
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 880         1       2  female  25.0      0      1            230433  26.0000
# 882         0       3  female  22.0      0      0              7552  10.5167
# 885         0       3  female  39.0      0      5            382652  29.1250
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
#
#     Cabin Embarked
# 1     C85        C
# ...

# %% [markdown]
# Renombrar columna

# %%
columnas={"Pclass":"PassengerClass"}
df3.rename(columns = columnas, inplace = True)
df3.head(2)
# Out:
#    Survived  PassengerClass     Sex   Age  SibSp  Parch     Ticket     Fare  \
# 0         0               3    male  22.0      1      0  A/5 21171   7.2500
# 1         1               1  female  38.0      1      0   PC 17599  71.2833
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C

# %% [markdown]
# ### Tabla de doble entrada

# %%
pd.crosstab(df3['Survived'],df3['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %% [markdown]
# ### Agrupar

# %%
df3.groupby(['PassengerClass','Sex'])['Survived'].sum()
# Out:
# PassengerClass  Sex
# 1               female    91
#                 male      45
# 2               female    70
#                 male      17
# 3               female    72
#                 male      47
# Name: Survived, dtype: int64

# %% [markdown]
# ### Reemplazar valores de columnas

# %%
ds_trabajo_reemplazo_valores=df3.copy()

ds_trabajo_reemplazo_valores.loc[ds_trabajo_reemplazo_valores.loc[:,"Survived"]==1,"Survived"]=True
ds_trabajo_reemplazo_valores.loc[ds_trabajo_reemplazo_valores.loc[:,"Survived"]==0,"Survived"]=False

ds_trabajo_reemplazo_valores.head()
# Out:
#   Survived  PassengerClass     Sex   Age  SibSp  Parch            Ticket  \
# 0    False               3    male  22.0      1      0         A/5 21171
# 1     True               1  female  38.0      1      0          PC 17599
# 2     True               3  female  26.0      0      0  STON/O2. 3101282
# 3     True               1  female  35.0      1      0            113803
# 4    False               3    male  35.0      0      0            373450
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# 2   7.9250   NaN        S
# 3  53.1000  C123        S
# 4   8.0500   NaN        S

# %%
ds_trabajo_reemplazo_valores=df3.copy()

ds_trabajo_reemplazo_valores.loc[:,"Survived"].replace(to_replace=[0,1],value=[False,True],inplace=True)

ds_trabajo_reemplazo_valores.head()
# Out:
#    Survived  PassengerClass     Sex   Age  SibSp  Parch            Ticket  \
# 0     False               3    male  22.0      1      0         A/5 21171
# 1      True               1  female  38.0      1      0          PC 17599
# 2      True               3  female  26.0      0      0  STON/O2. 3101282
# 3      True               1  female  35.0      1      0            113803
# 4     False               3    male  35.0      0      0            373450
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# 2   7.9250   NaN        S
# 3  53.1000  C123        S
# 4   8.0500   NaN        S

# %% [markdown]
# #<center> Merge</center>
#
# Ejemplo extraido de https://github.com/shanealynn/Pandas-Merge

# %%
user_usage = pd.read_csv("/content/drive/MyDrive/Labo Datos/Notebooks Ciencia de Datos/datasets/user_usage.csv")
user_device = pd.read_csv("/content/drive/MyDrive/Labo Datos/Notebooks Ciencia de Datos/datasets/user_device.csv")
devices = pd.read_csv("/content/drive/MyDrive/Labo Datos/Notebooks Ciencia de Datos/datasets/android_devices.csv")

devices.rename(columns={"Retail Branding": "manufacturer"}, inplace=True)

# %% [markdown]
# #### Merge 1

# %% [markdown]
# Supongamos que necesitamos obtener estadísticas de distintos tipos de dispositivos celulares.
#
# Unamos los dataset user_usage con user_device utilizando la columna user_id, que se común a los dos.

# %%
result = pd.merge(user_usage,
                 user_device[['use_id', 'platform', 'device']],
                 on='use_id')
result.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#   platform    device
# 0  android  GT-I9505
# 1  android  SM-G930F
# 2  android  SM-G930F
# 3  android     D2303
# 4  android  SM-G361F

# %% [markdown]
# Veamos que pasó?

# %%
print("Dimensiones user_usage: {}".format(user_usage.shape))
print("Dimensiones user_device : {}".format(user_device[['use_id', 'platform', 'device']].shape))
print("result",result.shape)
user_usage['use_id'].isin(user_device['use_id']).value_counts()
# Out:
# Dimensiones user_usage: (240, 4)
# Dimensiones user_device : (272, 3)
# result (159, 6)
# True     159
# False     81
# Name: use_id, dtype: int64

# %% [markdown]
# Sólo obtenemos los registros con user_id en ambos datasets (159)

# %% [markdown]
# #### Merge 2 - Left join

# %% [markdown]
# Left join, mantiene todas las filas del dataset de la izquierda, en este caso "user_usage" mientras que las columnas del dataset de la derecha se completarán sólo si existen datos vinculados en esa tabla, sino se completan con valores Nan.

# %%
result = pd.merge(user_usage,
                 user_device[['use_id', 'platform', 'device']],
                 on='use_id', how='left')

print("user_usage dimensions: {}".format(user_usage.shape))
print("result dimensions: {}".format(result.shape))
print("There are {} missing values in the result.".format(result['device'].isnull().sum()))
# Out:
# user_usage dimensions: (240, 4)
# result dimensions: (240, 6)
# There are 81 missing values in the result.

# %%
result.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#   platform    device
# 0  android  GT-I9505
# 1  android  SM-G930F
# 2  android  SM-G930F
# 3  android     D2303
# 4  android  SM-G361F

# %%
result.tail()
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 235                   260.66                   68.44      896.96   25008
# 236                    97.12                   36.50     2815.00   25040
# 237                   355.93                   12.37     6828.09   25046
# 238                   632.06                  120.46     1453.16   25058
# 239                   488.70                  906.92     3089.85   25220
#
#     platform device
# 235      NaN    NaN
# 236      NaN    NaN
# 237      NaN    NaN
# 238      NaN    NaN
# 239      NaN    NaN

# %% [markdown]
# #### Merge 3 - Right join
#
# Right join, mantiene todas las filas del dataset de la derecha, en este caso "user_device" mientras que las columnas del dataset de la izquierda se completarán sólo si existen datos vinculados en esa tabla, sino se completan con valores Nan.

# %%
result = pd.merge(user_usage,
                 user_device[['use_id', 'platform', 'device']],
                 on='use_id', how='right')

print("user_device dimensions: {}".format(user_device.shape))
print("result dimensions: {}".format(result.shape))
print("There are {} missing values in the 'monthly_mb' column in the result.".format(
        result['monthly_mb'].isnull().sum()))
print("There are {} missing values in the 'platform' column in the result.".format(
        result['platform'].isnull().sum()))
# Out:
# user_device dimensions: (272, 6)
# result dimensions: (272, 6)
# There are 113 missing values in the 'monthly_mb' column in the result.
# There are 0 missing values in the 'platform' column in the result.

# %% [markdown]
# #### Merge 4 - Outer Join
#
# Outer join mantiene todas las filas de ambos datasets, completando por cada fila los campos correspondientes a ambos datasets si se pueden vincular, y completando con Nans los campos correspondients al dataset derecho o izquierdo según corresponda en cada de no existir contraparte.

# %%
print("There are {} unique values of use_id in our dataframes.".format(
        pd.concat([user_usage['use_id'], user_device['use_id']]).unique().shape[0]))
result = pd.merge(user_usage,
                 user_device[['use_id', 'platform', 'device']],
                 on='use_id', how='outer', indicator=True)

print("Outer merge result has {} rows.".format(result.shape))

print("There are {} rows with no missing values.".format(
    (result.apply(lambda x: x.isnull().sum(), axis=1) == 0).sum()))
# Out:
# There are 353 unique values of use_id in our dataframes.
# Outer merge result has (353, 7) rows.
# There are 159 rows with no missing values.

# %% [markdown]
# ### Merge Final - sumemos un merge con la tabla user_device

# %%
# First, add the platform and device to the user usage.
result = pd.merge(user_usage,
                 user_device[['use_id', 'platform', 'device']],
                 on='use_id',
                 how='left')

# Now, based on the "device" column in result, match the "Model" column in devices.
devices.rename(columns={"Retail Branding": "manufacturer"}, inplace=True)
result = pd.merge(result,
                  devices[['manufacturer', 'Model']],
                  left_on='device',
                  right_on='Model',
                  how='left')

result.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#   platform    device manufacturer     Model
# 0  android  GT-I9505      Samsung  GT-I9505
# 1  android  SM-G930F      Samsung  SM-G930F
# 2  android  SM-G930F      Samsung  SM-G930F
# 3  android     D2303         Sony     D2303
# 4  android  SM-G361F      Samsung  SM-G361F

# %% [markdown]
# Como resultado final calculamos algunas estadísticas por Marca de dispositivo

# %%
result.groupby("manufacturer").agg({
        "outgoing_mins_per_month": "mean",
        "outgoing_sms_per_month": "mean",
        "monthly_mb": "mean",
        "use_id": "count"
    })
# Out:
#               outgoing_mins_per_month  outgoing_sms_per_month    monthly_mb  \
# manufacturer
# HTC                        299.842955               93.059318   5144.077955
# Huawei                      81.526667                9.500000   1561.226667
# LGE                        111.530000               12.760000   1557.330000
# Lava                        60.650000              261.900000  12458.670000
# Lenovo                     215.920000               12.930000   1557.330000
# Motorola                    95.127500               65.666250   3946.500000
# OnePlus                    354.855000               48.330000   6575.410000
# Samsung                    191.010093               92.390463   4017.318889
# Sony                       177.315625               40.176250   3212.000625
# Vodafone                    42.750000               46.830000   5191.120000
# ZTE                         42.750000               46.830000   5191.120000
#
#               use_id
# manufacturer
# ...
